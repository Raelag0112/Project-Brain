# %%
# %load_ext autoreload
# %autoreload 2
from lesymap_utils import *
from lesymap_experiments import *
# Out:
# The sklearn.linear_model.coordinate_descent module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.linear_model. Anything that cannot be imported from sklearn.linear_model is now part of the private API.

# %%
X_culled1 = pd.read_excel("X_culled.xlsx")

# %%
area3 = bootstrap_AUCs(X_culled1, 'SVR', 1, n_bs=5, rois = [100, 101], scenario = "XOR", n_jobs=30)
print(area3)
print(np.mean(area3))
# Out:
# nombre de 1 : 12
# 0 th bootstrap sample selected
# nombre de 1 : 15
# 1 th bootstrap sample selected
# nombre de 1 : 15
# 2 th bootstrap sample selected
# nombre de 1 : 16
# 3 th bootstrap sample selected
# nombre de 1 : 16
# 4 th bootstrap sample selected
# [Parallel(n_jobs=30)]: Using backend LokyBackend with 30 concurrent workers.
# [Parallel(n_jobs=30)]: Done   2 out of   5 | elapsed:   13.1s remaining:   19.6s
# [Parallel(n_jobs=30)]: Done   3 out of   5 | elapsed:   13.1s remaining:    8.7s
# [Parallel(n_jobs=30)]: Done   5 out of   5 | elapsed:   13.1s remaining:    0.0s
# [Parallel(n_jobs=30)]: Done   5 out of   5 | elapsed:   13.1s finished
# [0.50558659 0.50558659 0.50558659 0.50558659 0.50558659]
# 0.505586592178771

# %%
area = bootstrap_AUCs(X_culled1, 'SVR', 1, n_bs=5, rois = [100, 101], scenario = "OR", n_jobs=30)
print(area)
print(np.mean(area))
# Out:
# 0 th bootstrap sample selected
# 1 th bootstrap sample selected
# 2 th bootstrap sample selected
# 3 th bootstrap sample selected
# 4 th bootstrap sample selected
# [Parallel(n_jobs=30)]: Using backend LokyBackend with 30 concurrent workers.
# [Parallel(n_jobs=30)]: Done   2 out of   5 | elapsed:    8.2s remaining:   12.4s
# [Parallel(n_jobs=30)]: Done   3 out of   5 | elapsed:    8.2s remaining:    5.4s
# [Parallel(n_jobs=30)]: Done   5 out of   5 | elapsed:    8.3s remaining:    0.0s
# [Parallel(n_jobs=30)]: Done   5 out of   5 | elapsed:    8.3s finished
# [0.04852092 0.50558659 0.61309524 0.03126751 0.03233401]
# 0.24616085432756848
