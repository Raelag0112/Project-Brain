# %%
# %load_ext autoreload
# %autoreload 2
from lesymap_utils import *
from lesymap_experiments import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
X_culled1 = pd.read_excel("X_culled.xlsx")

# %%
area3 = bootstrap_AUCs(X_culled1, 'SVR', 10, n_bs=5, rois = [100, 101], scenario = "XOR", n_jobs=30)
print(area3)
print(np.mean(area3))
# Out:
# nombre de 1 : 18
# 0 th bootstrap sample selected
# nombre de 1 : 10
# 1 th bootstrap sample selected
# nombre de 1 : 14
# 2 th bootstrap sample selected
# nombre de 1 : 13
# 3 th bootstrap sample selected
# nombre de 1 : 24
# 4 th bootstrap sample selected
# [Parallel(n_jobs=30)]: Using backend LokyBackend with 30 concurrent workers.
# [Parallel(n_jobs=30)]: Done   2 out of   5 | elapsed:    7.5s remaining:   11.3s
# [Parallel(n_jobs=30)]: Done   3 out of   5 | elapsed:    7.5s remaining:    4.9s
# [Parallel(n_jobs=30)]: Done   5 out of   5 | elapsed:    7.5s remaining:    0.0s
# [Parallel(n_jobs=30)]: Done   5 out of   5 | elapsed:    7.5s finished
# [0.08755475 0.50558659 0.39211957 0.06428571 0.50422142]
# 0.3107536082600724

# %%
area = bootstrap_AUCs(X_culled1, 'SVR', SNR=5, n_bs=2, rois = [100, 101], scenario = "OR", n_jobs=30)
print(area)
print(np.mean(area))
# Out:
# 42
# 96
# [5. 7.]
# 41
# 92
# [ 7. 10.]
# 41
# 92
# [ 7. 10.]
# 46
# 91
# [4. 9.]
# 46
# 85
# [ 8. 11.]
# 53
# 83
# [ 3. 11.]
# 47
# 90
# [ 1. 12.]
# 46
# 90
# [ 3. 11.]
# 39
# 94
# [ 5. 12.]
# [Parallel(n_jobs=30)]: Using backend LokyBackend with 30 concurrent workers.
# [0.79166667 0.54020468]
# 0.6659356725146199
# [Parallel(n_jobs=30)]: Done   2 out of   2 | elapsed:    3.8s remaining:    0.0s
# [Parallel(n_jobs=30)]: Done   2 out of   2 | elapsed:    3.8s finished
