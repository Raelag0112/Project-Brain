# %%
# %load_ext autoreload
# %autoreload 2
from lesymap_utils import *
from lesymap_experiments import *
# Out:
# The sklearn.linear_model.coordinate_descent module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.linear_model. Anything that cannot be imported from sklearn.linear_model is now part of the private API.

# %%
X_culled1 = pd.read_excel("X_culled.xlsx")

# %%
area3 = bootstrap_AUCs(X_culled1, 'RF+SHAP', 10, n_bs=5, rois = [100, 101], scenario = "OR", n_jobs=30)
print(area3)
print(np.mean(area3))
# Out:
# [Parallel(n_jobs=30)]: Using backend LokyBackend with 30 concurrent workers.
# [Parallel(n_jobs=30)]: Done   2 out of   5 | elapsed:   34.1s remaining:   51.2s
# [Parallel(n_jobs=30)]: Done   3 out of   5 | elapsed:   47.3s remaining:   31.5s
# [Parallel(n_jobs=30)]: Done   5 out of   5 | elapsed:   48.0s remaining:    0.0s
# [Parallel(n_jobs=30)]: Done   5 out of   5 | elapsed:   48.0s finished
# [0.50419779 0.50419779 0.50419779 0.50419779 0.50419779]
# 0.5041977904714079
